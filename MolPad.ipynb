# %%
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit import RDConfig
import os
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw
from rdkit.Chem.Subshape import SubshapeBuilder,SubshapeAligner,SubshapeObjects

# %%
M2d = [x for x in Chem.SDMolSupplier('C6H8O4_conv.sdf')]
Draw.MolsToGridImage(M2d[:75],molsPerRow=5)
# Out:
# <PIL.Image.Image image mode=RGBA size=1000x200 at 0x2B525900E610>

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit import RDConfig
import os
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw
from rdkit.Chem.Subshape import SubshapeBuilder,SubshapeAligner,SubshapeObjects

MMM =[x for x in Chem.SDMolSupplier('%s.sdf'%(FORMULA))]
# 3D FILE
fff = open('3D_%s.sdf'%(FORMULA),'w')
dddmol = ""
for i in MMM :
    i = Chem.AddHs(i)
    AllChem.Compute2DCoords(i)
    AllChem.EmbedMolecule(i)
    AllChem.UFFOptimizeMolecule(i)
    dddmol = dddmol+ Chem.MolToMolBlock(i) +'$$$$\n'
fff.write(dddmol)
fff.close()

# %%
M3d = [x for x in Chem.SDMolSupplier('3D_%s.sdf'%(FORMULA))]

# %%
Draw.MolsToGridImage(M2d[:8],molsPerRow=4)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x200 at 0x2B0CB07E0AD0>

# %%
Draw.MolsToGridImage(M3d[:8],molsPerRow=4)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x200 at 0x2B1C30265350>

# %% [raw]
# ### STEP1 : Add 'v2000'  in sdf file

# %% [markdown]
# ### Time required graph

# %%
import numpy as np
import matplotlib.pyplot as plt


fig = plt.figure()
ax = fig.add_subplot(1,1,1)
#ax.set(xlim=[0., 7.], ylim=[0., 50.])
 
x = [1383,23838,61085580]
y = [0.2,1.0,7455]
 
ax.plot(x, y,'o')
plt.show()
